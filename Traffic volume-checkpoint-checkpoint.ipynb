# %%
# importing the necessary libraries
import pandas as pd
import numpy as np
import seaborn as sns
import sklearn as sk

from sklearn import linear_model
from sklearn import tree
from sklearn import ensemble
from sklearn import svm

# %%
# !pip install xgboost
import xgboost
# Out:
# Requirement already satisfied: xgboost in c:\users\nukal\anaconda3\lib\site-packages (3.0.2)
# Requirement already satisfied: numpy in c:\users\nukal\anaconda3\lib\site-packages (from xgboost) (2.1.3)
# Requirement already satisfied: scipy in c:\users\nukal\anaconda3\lib\site-packages (from xgboost) (1.15.3)

# %%
import pandas as pd

data = pd.read_csv(r"C:\Users\nukal\TrafficVolumeApp\Cleandata.csv")

# %%
data
# Out:
#        Unnamed: 0  holiday    temp  rain  snow  weather        date      Time  \
# 0               0        7  288.28   0.0   0.0        1  02-10-2012  09:00:00
# 1               1        7  289.36   0.0   0.0        1  02-10-2012  10:00:00
# 2               2        7  289.58   0.0   0.0        1  02-10-2012  11:00:00
# 3               3        7  290.13   0.0   0.0        1  02-10-2012  12:00:00
# 4               4        7  291.14   0.0   0.0        1  02-10-2012  13:00:00
# ...           ...      ...     ...   ...   ...      ...         ...       ...
# 48199       48199        7  283.45   0.0   0.0        1  30-09-2018  19:00:00
# 48200       48200        7  282.76   0.0   0.0        1  30-09-2018  20:00:00
# 48201       48201        7  282.73   0.0   0.0       10  30-09-2018  21:00:00
# 48202       48202        7  282.09   0.0   0.0        1  30-09-2018  22:00:00
# 48203       48203        7  282.12   0.0   0.0        1  30-09-2018  23:00:00
#
#        traffic_volume
# 0                5545
# 1                4516
# 2                4767
# 3                5026
# 4                4918
# ...               ...
# 48199            3543
# 48200            2781
# 48201            2159
# 48202            1450
# 48203             954
#
# [48204 rows x 9 columns]

# %%
data['holiday'].fillna('None', inplace=True)
# Out:
# C:\Users\nukal\AppData\Local\Temp\ipykernel_11968\2442072650.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['holiday'].fillna('None', inplace=True)

# %%
data
# Out:
#        Unnamed: 0  holiday    temp  rain  snow  weather        date      Time  \
# 0               0        7  288.28   0.0   0.0        1  02-10-2012  09:00:00
# 1               1        7  289.36   0.0   0.0        1  02-10-2012  10:00:00
# 2               2        7  289.58   0.0   0.0        1  02-10-2012  11:00:00
# 3               3        7  290.13   0.0   0.0        1  02-10-2012  12:00:00
# 4               4        7  291.14   0.0   0.0        1  02-10-2012  13:00:00
# ...           ...      ...     ...   ...   ...      ...         ...       ...
# 48199       48199        7  283.45   0.0   0.0        1  30-09-2018  19:00:00
# 48200       48200        7  282.76   0.0   0.0        1  30-09-2018  20:00:00
# 48201       48201        7  282.73   0.0   0.0       10  30-09-2018  21:00:00
# 48202       48202        7  282.09   0.0   0.0        1  30-09-2018  22:00:00
# 48203       48203        7  282.12   0.0   0.0        1  30-09-2018  23:00:00
#
#        traffic_volume
# 0                5545
# 1                4516
# 2                4767
# 3                5026
# 4                4918
# ...               ...
# 48199            3543
# 48200            2781
# 48201            2159
# 48202            1450
# 48203             954
#
# [48204 rows x 9 columns]

# %%
#uesd to understand the descriptive analyses of the data
data.describe()
# Out:
#          Unnamed: 0       holiday          temp          rain          snow  \
# count  48204.000000  48204.000000  48204.000000  48204.000000  48204.000000
# mean   24101.500000      6.997780    281.205351      0.334278      0.000222
# std    13915.440525      0.139999     13.336338     44.789133      0.008168
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%    12050.750000      7.000000    272.180000      0.000000      0.000000
# 50%    24101.500000      7.000000    282.429000      0.000000      0.000000
# 75%    36152.250000      7.000000    291.800000      0.000000      0.000000
# max    48203.000000     11.000000    310.070000   9831.300000      0.510000
#
#             weather  traffic_volume
# count  48204.000000    48204.000000
# mean       2.576695     3259.818355
# std        2.783488     1986.860670
# min        0.000000        0.000000
# 25%        0.000000     1193.000000
# 50%        1.000000     3380.000000
# 75%        5.000000     4933.000000
# max       10.000000     7280.000000

# %%
#displaying first 5 columns of the data
data.head()
# Out:
#    Unnamed: 0  holiday    temp  rain  snow  weather        date      Time  \
# 0           0        7  288.28   0.0   0.0        1  02-10-2012  09:00:00
# 1           1        7  289.36   0.0   0.0        1  02-10-2012  10:00:00
# 2           2        7  289.58   0.0   0.0        1  02-10-2012  11:00:00
# 3           3        7  290.13   0.0   0.0        1  02-10-2012  12:00:00
# 4           4        7  291.14   0.0   0.0        1  02-10-2012  13:00:00
#
#    traffic_volume
# 0            5545
# 1            4516
# 2            4767
# 3            5026
# 4            4918

# %%
#basic information of the data
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48204 entries, 0 to 48203
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      48204 non-null  int64
#  1   holiday         48204 non-null  int64
#  2   temp            48204 non-null  float64
#  3   rain            48204 non-null  float64
#  4   snow            48204 non-null  float64
#  5   weather         48204 non-null  int64
#  6   date            48204 non-null  object
#  7   Time            48204 non-null  object
#  8   traffic_volume  48204 non-null  int64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 3.3+ MB

# %%
#displaying first 5 columns of the data
data.head()
# Out:
#    Unnamed: 0  holiday    temp  rain  snow  weather        date      Time  \
# 0           0        7  288.28   0.0   0.0        1  02-10-2012  09:00:00
# 1           1        7  289.36   0.0   0.0        1  02-10-2012  10:00:00
# 2           2        7  289.58   0.0   0.0        1  02-10-2012  11:00:00
# 3           3        7  290.13   0.0   0.0        1  02-10-2012  12:00:00
# 4           4        7  291.14   0.0   0.0        1  02-10-2012  13:00:00
#
#    traffic_volume
# 0            5545
# 1            4516
# 2            4767
# 3            5026
# 4            4918

# %%
data.isnull().sum()
# Out:
# Unnamed: 0        0
# holiday           0
# temp              0
# rain              0
# snow              0
# weather           0
# date              0
# Time              0
# traffic_volume    0
# dtype: int64

# %%
data['temp'].fillna(data['temp'].mean(), inplace=True)
data['rain'].fillna(data['rain'].mean(), inplace=True)
data['snow'].fillna(data['snow'].mean(), inplace=True)
# Out:
# C:\Users\nukal\AppData\Local\Temp\ipykernel_11968\4238678335.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['temp'].fillna(data['temp'].mean(), inplace=True)
# C:\Users\nukal\AppData\Local\Temp\ipykernel_11968\4238678335.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['rain'].fillna(data['rain'].mean(), inplace=True)
# C:\Users\nukal\AppData\Local\Temp\ipykernel_11968\4238678335.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['snow'].fillna(data['snow'].mean(), inplace=True)

# %%
from collections import Counter
print(Counter(data['weather']))
# Out:
# Counter({1: 15193, 0: 13383, 5: 5942, 6: 5665, 8: 2875, 2: 1818, 4: 1359, 10: 1033, 3: 912, 7: 20, 9: 4})

# %%
data['weather'].fillna('Clouds', inplace=True)
# Out:
# C:\Users\nukal\AppData\Local\Temp\ipykernel_11968\97763455.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['weather'].fillna('Clouds', inplace=True)

# %%
data.isnull().sum()
# Out:
# Unnamed: 0        0
# holiday           0
# temp              0
# rain              0
# snow              0
# weather           0
# date              0
# Time              0
# traffic_volume    0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

# Apply to selected categorical columns
for col in ['holiday', 'weather']:
    data[col] = data[col].fillna('None')  # Fill missing first
    data[col] = le.fit_transform(data[col])

# %%
data
# Out:
#        Unnamed: 0  holiday    temp  rain  snow  weather        date      Time  \
# 0               0        7  288.28   0.0   0.0        1  02-10-2012  09:00:00
# 1               1        7  289.36   0.0   0.0        1  02-10-2012  10:00:00
# 2               2        7  289.58   0.0   0.0        1  02-10-2012  11:00:00
# 3               3        7  290.13   0.0   0.0        1  02-10-2012  12:00:00
# 4               4        7  291.14   0.0   0.0        1  02-10-2012  13:00:00
# ...           ...      ...     ...   ...   ...      ...         ...       ...
# 48199       48199        7  283.45   0.0   0.0        1  30-09-2018  19:00:00
# 48200       48200        7  282.76   0.0   0.0        1  30-09-2018  20:00:00
# 48201       48201        7  282.73   0.0   0.0       10  30-09-2018  21:00:00
# 48202       48202        7  282.09   0.0   0.0        1  30-09-2018  22:00:00
# 48203       48203        7  282.12   0.0   0.0        1  30-09-2018  23:00:00
#
#        traffic_volume
# 0                5545
# 1                4516
# 2                4767
# 3                5026
# 4                4918
# ...               ...
# 48199            3543
# 48200            2781
# 48201            2159
# 48202            1450
# 48203             954
#
# [48204 rows x 9 columns]

# %%
data[["hours", "minutes", "seconds"]]=data["Time"].str.split(":", expand=True)

# %%
data[["day", "month", "year"]]=data["date"].str.split("-", expand=True)

# %%
data.drop(columns=['date','Time'], inplace=True)

# %%
data
# Out:
#        Unnamed: 0  holiday    temp  rain  snow  weather  traffic_volume hours  \
# 0               0        7  288.28   0.0   0.0        1            5545    09
# 1               1        7  289.36   0.0   0.0        1            4516    10
# 2               2        7  289.58   0.0   0.0        1            4767    11
# 3               3        7  290.13   0.0   0.0        1            5026    12
# 4               4        7  291.14   0.0   0.0        1            4918    13
# ...           ...      ...     ...   ...   ...      ...             ...   ...
# 48199       48199        7  283.45   0.0   0.0        1            3543    19
# 48200       48200        7  282.76   0.0   0.0        1            2781    20
# 48201       48201        7  282.73   0.0   0.0       10            2159    21
# 48202       48202        7  282.09   0.0   0.0        1            1450    22
# 48203       48203        7  282.12   0.0   0.0        1             954    23
#
#       minutes seconds day month  year
# 0          00      00  02    10  2012
# 1          00      00  02    10  2012
# 2          00      00  02    10  2012
# 3          00      00  02    10  2012
# 4          00      00  02    10  2012
# ...       ...     ...  ..   ...   ...
# 48199      00      00  30    09  2018
# 48200      00      00  30    09  2018
# 48201      00      00  30    09  2018
# 48202      00      00  30    09  2018
# 48203      00      00  30    09  2018
#
# [48204 rows x 13 columns]

# %%
data.corr()
# Out:
#                 Unnamed: 0   holiday      temp      rain      snow   weather  \
# Unnamed: 0        1.000000 -0.002631  0.159861 -0.000409 -0.007469  0.041347
# holiday          -0.002631  1.000000 -0.000472  0.000066  0.000432 -0.004328
# temp              0.159861 -0.000472  1.000000  0.009070 -0.019758 -0.033559
# rain             -0.000409  0.000066  0.009070  1.000000 -0.000090  0.009542
# snow             -0.007469  0.000432 -0.019758 -0.000090  1.000000  0.036662
# weather           0.041347 -0.004328 -0.033559  0.009542  0.036662  1.000000
# traffic_volume    0.006873  0.018676  0.130034  0.004714  0.000735 -0.040035
# hours            -0.005537  0.026040  0.111811  0.003421  0.009850 -0.053575
# minutes                NaN       NaN       NaN       NaN       NaN       NaN
# seconds                NaN       NaN       NaN       NaN       NaN       NaN
# day               0.024668  0.007694  0.022763 -0.002293  0.015784  0.022539
# month            -0.022473 -0.010104  0.223837  0.001298  0.020420  0.025809
# year              0.976919 -0.001422  0.134861  0.000442 -0.003530  0.037242
#
#                 traffic_volume     hours  minutes  seconds       day  \
# Unnamed: 0            0.006873 -0.005537      NaN      NaN  0.024668
# holiday               0.018676  0.026040      NaN      NaN  0.007694
# temp                  0.130034  0.111811      NaN      NaN  0.022763
# rain                  0.004714  0.003421      NaN      NaN -0.002293
# snow                  0.000735  0.009850      NaN      NaN  0.015784
# weather              -0.040035 -0.053575      NaN      NaN  0.022539
# traffic_volume        1.000000  0.352401      NaN      NaN -0.007587
# hours                 0.352401  1.000000      NaN      NaN -0.009373
# minutes                    NaN       NaN      NaN      NaN       NaN
# seconds                    NaN       NaN      NaN      NaN       NaN
# day                  -0.007587 -0.009373      NaN      NaN  1.000000
# month                -0.002533  0.001865      NaN      NaN  0.008614
# year                  0.004753 -0.007542      NaN      NaN  0.012192
#
#                    month      year
# Unnamed: 0     -0.022473  0.976919
# holiday        -0.010104 -0.001422
# temp            0.223837  0.134861
# rain            0.001298  0.000442
# snow            0.020420 -0.003530
# weather         0.025809  0.037242
# traffic_volume -0.002533  0.004753
# hours           0.001865 -0.007542
# minutes              NaN       NaN
# seconds              NaN       NaN
# day             0.008614  0.012192
# month           1.000000 -0.158688
# year           -0.158688  1.000000

# %%
y= data['traffic_volume']
x= data.drop('traffic_volume',axis=1)

# %%
x
# Out:
#        Unnamed: 0  holiday    temp  rain  snow  weather hours minutes seconds  \
# 0               0        7  288.28   0.0   0.0        1    09      00      00
# 1               1        7  289.36   0.0   0.0        1    10      00      00
# 2               2        7  289.58   0.0   0.0        1    11      00      00
# 3               3        7  290.13   0.0   0.0        1    12      00      00
# 4               4        7  291.14   0.0   0.0        1    13      00      00
# ...           ...      ...     ...   ...   ...      ...   ...     ...     ...
# 48199       48199        7  283.45   0.0   0.0        1    19      00      00
# 48200       48200        7  282.76   0.0   0.0        1    20      00      00
# 48201       48201        7  282.73   0.0   0.0       10    21      00      00
# 48202       48202        7  282.09   0.0   0.0        1    22      00      00
# 48203       48203        7  282.12   0.0   0.0        1    23      00      00
#
#       day month  year
# 0      02    10  2012
# 1      02    10  2012
# 2      02    10  2012
# 3      02    10  2012
# 4      02    10  2012
# ...    ..   ...   ...
# 48199  30    09  2018
# 48200  30    09  2018
# 48201  30    09  2018
# 48202  30    09  2018
# 48203  30    09  2018
#
# [48204 rows x 12 columns]

# %%
y
# Out:
# 0        5545
# 1        4516
# 2        4767
# 3        5026
# 4        4918
#          ...
# 48199    3543
# 48200    2781
# 48201    2159
# 48202    1450
# 48203     954
# Name: traffic_volume, Length: 48204, dtype: int64

# %%
names=x.columns
#from sklearn.preprocessing import scale
#x=scale(x)
#x=pd.DataFrame(x,columns=names)
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x_scaled = scaler.fit_transform(x)
x = pd.DataFrame(x_scaled, columns=names)

# %%
# ✅ Save feature names here
feature_names = x.columns.tolist()
import pickle
pickle.dump(feature_names, open("features.pkl", "wb"))

# %%
x.head()
# Out:
#    Unnamed: 0   holiday      temp      rain      snow   weather     hours  \
# 0   -1.732015  0.015856  0.530485 -0.007463 -0.027235 -0.566452 -0.345548
# 1   -1.731943  0.015856  0.611467 -0.007463 -0.027235 -0.566452 -0.201459
# 2   -1.731871  0.015856  0.627964 -0.007463 -0.027235 -0.566452 -0.057371
# 3   -1.731799  0.015856  0.669205 -0.007463 -0.027235 -0.566452  0.086718
# 4   -1.731727  0.015856  0.744939 -0.007463 -0.027235 -0.566452  0.230807
#
#    minutes  seconds       day    month      year
# 0      0.0      0.0 -1.574903  1.02758 -1.855294
# 1      0.0      0.0 -1.574903  1.02758 -1.855294
# 2      0.0      0.0 -1.574903  1.02758 -1.855294
# 3      0.0      0.0 -1.574903  1.02758 -1.855294
# 4      0.0      0.0 -1.574903  1.02758 -1.855294

# %%
x
# Out:
#        Unnamed: 0   holiday      temp      rain      snow   weather     hours  \
# 0       -1.732015  0.015856  0.530485 -0.007463 -0.027235 -0.566452 -0.345548
# 1       -1.731943  0.015856  0.611467 -0.007463 -0.027235 -0.566452 -0.201459
# 2       -1.731871  0.015856  0.627964 -0.007463 -0.027235 -0.566452 -0.057371
# 3       -1.731799  0.015856  0.669205 -0.007463 -0.027235 -0.566452  0.086718
# 4       -1.731727  0.015856  0.744939 -0.007463 -0.027235 -0.566452  0.230807
# ...           ...       ...       ...       ...       ...       ...       ...
# 48199    1.731727  0.015856  0.168313 -0.007463 -0.027235 -0.566452  1.095340
# 48200    1.731799  0.015856  0.116574 -0.007463 -0.027235 -0.566452  1.239428
# 48201    1.731871  0.015856  0.114324 -0.007463 -0.027235  2.666935  1.383517
# 48202    1.731943  0.015856  0.066334 -0.007463 -0.027235 -0.566452  1.527606
# 48203    1.732015  0.015856  0.068584 -0.007463 -0.027235 -0.566452  1.671695
#
#        minutes  seconds       day     month      year
# 0          0.0      0.0 -1.574903  1.027580 -1.855294
# 1          0.0      0.0 -1.574903  1.027580 -1.855294
# 2          0.0      0.0 -1.574903  1.027580 -1.855294
# 3          0.0      0.0 -1.574903  1.027580 -1.855294
# 4          0.0      0.0 -1.574903  1.027580 -1.855294
# ...        ...      ...       ...       ...       ...
# 48199      0.0      0.0  1.635058  0.733478  1.313958
# 48200      0.0      0.0  1.635058  0.733478  1.313958
# 48201      0.0      0.0  1.635058  0.733478  1.313958
# 48202      0.0      0.0  1.635058  0.733478  1.313958
# 48203      0.0      0.0  1.635058  0.733478  1.313958
#
# [48204 rows x 12 columns]

# %%
x.head()
# Out:
#    holiday    temp  rain  snow  weather  hours  minutes  seconds  day  month  \
# 0        7  288.28   0.0   0.0        1      9        0        0    2     10
# 1        7  289.36   0.0   0.0        1     10        0        0    2     10
# 2        7  289.58   0.0   0.0        1     11        0        0    2     10
# 3        7  290.13   0.0   0.0        1     12        0        0    2     10
# 4        7  291.14   0.0   0.0        1     13        0        0    2     10
#
#    year
# 0  2012
# 1  2012
# 2  2012
# 3  2012
# 4  2012

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test= train_test_split(x,y,test_size=0.2,random_state=0)

# %%
# Import required libraries
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from xgboost import XGBRegressor

from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split


# Define all models
models = {
    "Linear Regression": LinearRegression(),
    "Decision Tree": DecisionTreeRegressor(),
    "Random Forest": RandomForestRegressor(),
    "SVM": SVR(),
    "XGBoost": XGBRegressor()
}

# Train, Predict, and Evaluate each model
for name, model in models.items():
    model.fit(x_train, y_train)
    predictions = model.predict(x_test)
    mse = mean_squared_error(y_test, predictions)
    r2 = r2_score(y_test, predictions)
    print(f"\n{name}")
    print(f"Mean Squared Error: {mse:.2f}")
    print(f"R² Score: {r2:.2f}")
# Out:
# Linear Regression
# Mean Squared Error: 3379261.70
# R² Score: 0.14
#
# Decision Tree
# Mean Squared Error: 1085290.02
# R² Score: 0.72
#
# Random Forest
# Mean Squared Error: 571376.36
# R² Score: 0.85
#
# SVM
# Mean Squared Error: 3072151.69
# R² Score: 0.21
#
# XGBoost
# Mean Squared Error: 571183.94
# R² Score: 0.85

# %%
# Import required libraries
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from xgboost import XGBRegressor

from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split


# Define all models
models = {
    "Linear Regression": LinearRegression(),
    "Decision Tree": DecisionTreeRegressor(),
    "Random Forest": RandomForestRegressor(),
    "SVM": SVR(),
    "XGBoost": XGBRegressor()
}

# Train, Predict, and Evaluate each model
for name, model in models.items():
    model.fit(x_train, y_train)
    predictions = model.predict(x_test)
    mse = mean_squared_error(y_test, predictions)
    r2 = r2_score(y_test, predictions)
    print(f"\n{name}")
    print(f"Mean Squared Error: {mse:.2f}")
    print(f"R² Score: {r2:.2f}")

# %%
# Save the scaler for future use
import pickle
best_model = models["Random Forest"]
pickle.dump(best_model, open("model.pkl", 'wb'))
pickle.dump(scaler, open("scale.pkl", 'wb'))
